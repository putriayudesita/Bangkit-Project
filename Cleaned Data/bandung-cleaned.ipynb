# %% [markdown]
# ### Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st

# %% [markdown]
# ### Gathering Data

# %%
url = 'https://raw.githubusercontent.com/elsamaulida5/machine-learning/main/data/Laundry%20Bandung.csv'
data = pd.read_csv(url, encoding='latin1', na_values='*')
data
# Out:
#                                                   Name  Description  \
# 0    Laundryklin Sudirman ( Laundry Antar Jemput Ba...          NaN
# 1                                     The Laundry Room          NaN
# 2                       Nadhif Laundry ciroyom bandung          NaN
# 3                                Laundry Club Rajawali          NaN
# 4                                 EZpress Home Laundry          NaN
# ..                                                 ...          ...
# 295                                    PERTAMA LAUNDRY          NaN
# 296  Dr Laundry Ujung Berung (Laundry Kiloan dan La...          NaN
# 297                                   yayamama laundry          NaN
# 298                                       La ' Laundry          NaN
# 299                      GWASH LAUNDRY EXPRESS CIJAMBE          NaN
#
#                                            Fulladdress  \
# 0    Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...
# 1    Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...
# 2    Gg. Sastra No.272/78, Dungus Cariang, Kec. And...
# 3    Jl. Rajawali Barat No.25, Garuda, Kec. Andir, ...
# 4    Jl. Durman No.4, Kb. Jeruk, Kec. Andir, Kota B...
# ..                                                 ...
# 295  Jl. A.H. Nasution No.69-289, Pasanggrahan, Kec...
# 296  Pasir Endah, Kec. Ujung Berung, Kota Bandung, ...
# 297  3MRX+RFH, Unnamed Road, Cigending, Ujung Berun...
# 298  Jl. A.H. Nasution Komp. Ruko Ubertos No.46A, P...
# 299  Jl. Cijambe No.26, Pasir Endah, Kec. Ujung Ber...
#
#                                           Street       Municipality  \
# 0                      Jl. Jend. Sudirman No.486            Ciroyom
# 1                           Jl. Ciroyom No.95/77     Dungus Cariang
# 2                           Gg. Sastra No.272/78     Dungus Cariang
# 3                       Jl. Rajawali Barat No.25             Garuda
# 4                                Jl. Durman No.4          Kb. Jeruk
# ..                                           ...                ...
# 295                  Jl. A.H. Nasution No.69-289       Pasanggrahan
# 296                                  Pasir Endah  Kec. Ujung Berung
# 297                                     3MRX+RFH       Unnamed Road
# 298  Jl. A.H. Nasution Komp. Ruko Ubertos No.46A          Pakemitan
# 299                            Jl. Cijambe No.26        Pasir Endah
#
#          Categories     Time Zone  Amenities           Phone  \
# 0    Layanan Binatu  Asia/Jakarta        NaN  0851-7335-8871
# 1    Layanan Binatu  Asia/Jakarta        NaN  (022) 20562320
# 2            Binatu  Asia/Jakarta        NaN   (022) 6036296
# 3    Layanan Binatu  Asia/Jakarta        NaN  0851-7324-7944
# 4    Layanan Binatu  Asia/Jakarta        NaN  0823-2020-9878
# ..              ...           ...        ...             ...
# 295          Binatu  Asia/Jakarta        NaN  0813-2249-3162
# 296          Binatu  Asia/Jakarta        NaN             NaN
# 297  Layanan Binatu  Asia/Jakarta        NaN  0857-2100-3866
# 298          Binatu  Asia/Jakarta        NaN  0818-0946-7561
# 299  Layanan Binatu  Asia/Jakarta        NaN   0811-2439-194
#
#                                 Phones  ...  \
# 0    0851-7335-8871, +62 851-7335-8871  ...
# 1      (022) 20562320, +62 22 20562320  ...
# 2        (022) 6036296, +62 22 6036296  ...
# 3    0851-7324-7944, +62 851-7324-7944  ...
# 4    0823-2020-9878, +62 823-2020-9878  ...
# ..                                 ...  ...
# 295  0813-2249-3162, +62 813-2249-3162  ...
# 296                                NaN  ...
# 297  0857-2100-3866, +62 857-2100-3866  ...
# 298  0818-0946-7561, +62 818-0946-7561  ...
# 299    0811-2439-194, +62 811-2439-194  ...
#
#                                        Google Maps URL  Latitude   Longitude  \
# 0    https://www.google.com/maps?cid=94604019837086... -6.918552  107.586449
# 1    https://www.google.com/maps?cid=11162829296077... -6.909928  107.580838
# 2    https://www.google.com/maps?cid=16206958779682... -6.915349  107.585807
# 3    https://www.google.com/maps?cid=10211050715543... -6.911077  107.570868
# 4    https://www.google.com/maps?cid=89067263696846... -6.919917  107.599841
# ..                                                 ...       ...         ...
# 295  https://www.google.com/maps?cid=88520853708990... -6.919000  107.707990
# 296  https://www.google.com/maps?cid=81668063895076... -6.903565  107.690776
# 297  https://www.google.com/maps?cid=11701149317531... -6.907938  107.698734
# 298  https://www.google.com/maps?cid=57604493266910... -6.916080  107.695878
# 299  https://www.google.com/maps?cid=32656553201029... -6.909012  107.690770
#
#                                                Website         Domain  \
# 0                                                  NaN            NaN
# 1    https://www.instagram.com/the.laundry.room.ban...  instagram.com
# 2                                                  NaN            NaN
# 3         https://bit.ly/customer_laundryclub_rajawali         bit.ly
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 295                                                NaN            NaN
# 296                                                NaN            NaN
# 297                                                NaN            NaN
# 298                                                NaN            NaN
# 299                                                NaN            NaN
#
#                                          Opening Hours  \
# 0    Sabtu: [07.00-21.00], Minggu: [07.00-21.00], S...
# 1    Sabtu: [Buka 24 jam], Minggu: [Buka 24 jam], S...
# 2    Sabtu: [08.00-20.00], Minggu: [08.00-20.00], S...
# 3    Sabtu: [07.00-20.00], Minggu: [09.00-17.00], S...
# 4    Sabtu: [07.00-18.00], Minggu: [Tutup], Senin: ...
# ..                                                 ...
# 295  Sabtu: [07.00-19.00], Minggu: [Tutup], Senin: ...
# 296  Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
# 297  Sabtu: [08.00-17.00], Minggu: [10.00-16.30], S...
# 298  Sabtu: [08.00-21.00], Minggu: [08.00-21.00], S...
# 299  Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
#
#                                         Featured Image Cid  \
# 0    https://lh5.googleusercontent.com/p/AF1QipMUOc... NaN
# 1    https://lh5.googleusercontent.com/p/AF1QipOt-O... NaN
# 2    https://lh5.googleusercontent.com/p/AF1QipPN10... NaN
# 3    https://lh5.googleusercontent.com/p/AF1QipMERU... NaN
# 4    https://lh5.googleusercontent.com/p/AF1QipOy4x... NaN
# ..                                                 ...  ..
# 295  https://lh5.googleusercontent.com/p/AF1QipNLMJ... NaN
# 296  https://lh5.googleusercontent.com/p/AF1QipN7Vb... NaN
# 297  https://lh5.googleusercontent.com/p/AF1QipNMIG... NaN
# 298  https://lh5.googleusercontent.com/p/AF1QipMFbP... NaN
# 299  https://lh5.googleusercontent.com/p/AF1QipNULN... NaN
#
#                                        Fid                     Place Id
# 0    0x2e68e79071db287b:0x834a197b175b2ac0  ChIJeyjbcZDnaC4RwCpbF3sZSoM
# 1     0x2e68e7f0df99f179:0xf7dd569001abd82  ChIJefGZ3_DnaC4Rgr0aAGnVfQ8
# 2    0x2e68e60ebfffffff:0x167dde506f3c2578  ChIJ____vw7maC4ReCU8b1DefRY
# 3     0x2e68e5800133b9c9:0xe2bb1a70c5846e8  ChIJybkzAYDlaC4R6EZYDKexKw4
# 4    0x2e68e701066ee9a9:0x7b9b0c7180a8d40d  ChIJqeluBgHnaC4RDdSogHEMm3s
# ..                                     ...                          ...
# 295  0x2e68dd2e84c7b889:0x7ad8ecbe95df4eef  ChIJibjHhC7daC4R707flb7s2Ho
# 296  0x2e68dd0075038f47:0x7156532443fefe53  ChIJR48DdQDdaC4RU_7-QyRTVnE
# 297  0x2e68dd47e80e5595:0xa262d54f1741e536  ChIJlVUO6EfdaC4RNuVBF0_VYqI
# 298  0x2e68dd370c71ba53:0x4ff13a24780eb454  ChIJU7pxDDfdaC4RVLQOeCQ68U8
# 299  0x2e68dd7993e1f7d9:0x2d51f036219a4939  ChIJ2ffhk3ndaC4ROUmaITbwUS0
#
# [300 rows x 24 columns]

# %% [markdown]
# ### Processing Data

# %% [markdown]
# #### Dropping Unnecessary Columns

# %%
print(data.columns)
# Out:
# Index(['Name', 'Description', 'Fulladdress', 'Street', 'Municipality',
#        'Categories', 'Time Zone', 'Amenities', 'Phone', 'Phones', 'Claimed',
#        'Review Count', 'Average Rating', 'Review URL', 'Google Maps URL',
#        'Latitude', 'Longitude', 'Website', 'Domain', 'Opening Hours',
#        'Featured Image', 'Cid', 'Fid', 'Place Id'],
#       dtype='object')

# %%
columns_to_drop = ['Description', 'Street', 'Amenities', 'Phone', 'Cid', 'Fid', 'Place Id']

# %%
data.drop(columns_to_drop, axis='columns', inplace=True)

# %%
print(data.columns)
# Out:
# Index(['Name', 'Fulladdress', 'Municipality', 'Categories', 'Time Zone',
#        'Phones', 'Claimed', 'Review Count', 'Average Rating', 'Review URL',
#        'Google Maps URL', 'Latitude', 'Longitude', 'Website', 'Domain',
#        'Opening Hours', 'Featured Image'],
#       dtype='object')

# %% [markdown]
# #### Deleting Missing Value

# %%
data.isnull().sum()
# Out:
# Name                 0
# Fulladdress          0
# Municipality         0
# Categories           0
# Time Zone            0
# Phones              43
# Claimed              0
# Review Count         3
# Average Rating       3
# Review URL           3
# Google Maps URL      0
# Latitude             0
# Longitude            0
# Website            192
# Domain             192
# Opening Hours       37
# Featured Image       2
# dtype: int64

# %% [markdown]
# For preventing the decreasing number of data, all the missing value will be substitute with "None".

# %%
rows_to_change = ['Website', 'Domain', 'Phones', 'Review Count', 'Average Rating', 'Review URL', 'Opening Hours', 'Featured Image']
data[rows_to_change] = data[rows_to_change].fillna(value='None')
data
# Out:
#                                                   Name  \
# 0    Laundryklin Sudirman ( Laundry Antar Jemput Ba...
# 1                                     The Laundry Room
# 2                       Nadhif Laundry ciroyom bandung
# 3                                Laundry Club Rajawali
# 4                                 EZpress Home Laundry
# ..                                                 ...
# 295                                    PERTAMA LAUNDRY
# 296  Dr Laundry Ujung Berung (Laundry Kiloan dan La...
# 297                                   yayamama laundry
# 298                                       La ' Laundry
# 299                      GWASH LAUNDRY EXPRESS CIJAMBE
#
#                                            Fulladdress       Municipality  \
# 0    Jl. Jend. Sudirman No.486, Ciroyom, Kec. Andir...            Ciroyom
# 1    Jl. Ciroyom No.95/77, Dungus Cariang, Kec. And...     Dungus Cariang
# 2    Gg. Sastra No.272/78, Dungus Cariang, Kec. And...     Dungus Cariang
# 3    Jl. Rajawali Barat No.25, Garuda, Kec. Andir, ...             Garuda
# 4    Jl. Durman No.4, Kb. Jeruk, Kec. Andir, Kota B...          Kb. Jeruk
# ..                                                 ...                ...
# 295  Jl. A.H. Nasution No.69-289, Pasanggrahan, Kec...       Pasanggrahan
# 296  Pasir Endah, Kec. Ujung Berung, Kota Bandung, ...  Kec. Ujung Berung
# 297  3MRX+RFH, Unnamed Road, Cigending, Ujung Berun...       Unnamed Road
# 298  Jl. A.H. Nasution Komp. Ruko Ubertos No.46A, P...          Pakemitan
# 299  Jl. Cijambe No.26, Pasir Endah, Kec. Ujung Ber...        Pasir Endah
#
#          Categories     Time Zone                             Phones Claimed  \
# 0    Layanan Binatu  Asia/Jakarta  0851-7335-8871, +62 851-7335-8871     YES
# 1    Layanan Binatu  Asia/Jakarta    (022) 20562320, +62 22 20562320     YES
# 2            Binatu  Asia/Jakarta      (022) 6036296, +62 22 6036296      NO
# 3    Layanan Binatu  Asia/Jakarta  0851-7324-7944, +62 851-7324-7944     YES
# 4    Layanan Binatu  Asia/Jakarta  0823-2020-9878, +62 823-2020-9878     YES
# ..              ...           ...                                ...     ...
# 295          Binatu  Asia/Jakarta  0813-2249-3162, +62 813-2249-3162     YES
# 296          Binatu  Asia/Jakarta                               None     YES
# 297  Layanan Binatu  Asia/Jakarta  0857-2100-3866, +62 857-2100-3866      NO
# 298          Binatu  Asia/Jakarta  0818-0946-7561, +62 818-0946-7561     YES
# 299  Layanan Binatu  Asia/Jakarta    0811-2439-194, +62 811-2439-194      NO
#
#     Review Count Average Rating  \
# 0          151.0            4.8
# 1            3.0            5.0
# 2            6.0            4.7
# 3           33.0            4.9
# 4           50.0            4.2
# ..           ...            ...
# 295         24.0            4.7
# 296         12.0            4.4
# 297         12.0            5.0
# 298         16.0            4.4
# 299          7.0            5.0
#
#                                             Review URL  \
# 0    https://search.google.com/local/reviews?placei...
# 1    https://search.google.com/local/reviews?placei...
# 2    https://search.google.com/local/reviews?placei...
# 3    https://search.google.com/local/reviews?placei...
# 4    https://search.google.com/local/reviews?placei...
# ..                                                 ...
# 295  https://search.google.com/local/reviews?placei...
# 296  https://search.google.com/local/reviews?placei...
# 297  https://search.google.com/local/reviews?placei...
# 298  https://search.google.com/local/reviews?placei...
# 299  https://search.google.com/local/reviews?placei...
#
#                                        Google Maps URL  Latitude   Longitude  \
# 0    https://www.google.com/maps?cid=94604019837086... -6.918552  107.586449
# 1    https://www.google.com/maps?cid=11162829296077... -6.909928  107.580838
# 2    https://www.google.com/maps?cid=16206958779682... -6.915349  107.585807
# 3    https://www.google.com/maps?cid=10211050715543... -6.911077  107.570868
# 4    https://www.google.com/maps?cid=89067263696846... -6.919917  107.599841
# ..                                                 ...       ...         ...
# 295  https://www.google.com/maps?cid=88520853708990... -6.919000  107.707990
# 296  https://www.google.com/maps?cid=81668063895076... -6.903565  107.690776
# 297  https://www.google.com/maps?cid=11701149317531... -6.907938  107.698734
# 298  https://www.google.com/maps?cid=57604493266910... -6.916080  107.695878
# 299  https://www.google.com/maps?cid=32656553201029... -6.909012  107.690770
#
#                                                Website         Domain  \
# 0                                                 None           None
# 1    https://www.instagram.com/the.laundry.room.ban...  instagram.com
# 2                                                 None           None
# 3         https://bit.ly/customer_laundryclub_rajawali         bit.ly
# 4                                                 None           None
# ..                                                 ...            ...
# 295                                               None           None
# 296                                               None           None
# 297                                               None           None
# 298                                               None           None
# 299                                               None           None
#
#                                          Opening Hours  \
# 0    Sabtu: [07.00-21.00], Minggu: [07.00-21.00], S...
# 1    Sabtu: [Buka 24 jam], Minggu: [Buka 24 jam], S...
# 2    Sabtu: [08.00-20.00], Minggu: [08.00-20.00], S...
# 3    Sabtu: [07.00-20.00], Minggu: [09.00-17.00], S...
# 4    Sabtu: [07.00-18.00], Minggu: [Tutup], Senin: ...
# ..                                                 ...
# 295  Sabtu: [07.00-19.00], Minggu: [Tutup], Senin: ...
# 296  Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
# 297  Sabtu: [08.00-17.00], Minggu: [10.00-16.30], S...
# 298  Sabtu: [08.00-21.00], Minggu: [08.00-21.00], S...
# 299  Sabtu: [07.00-20.00], Minggu: [07.00-20.00], S...
#
#                                         Featured Image
# 0    https://lh5.googleusercontent.com/p/AF1QipMUOc...
# 1    https://lh5.googleusercontent.com/p/AF1QipOt-O...
# 2    https://lh5.googleusercontent.com/p/AF1QipPN10...
# 3    https://lh5.googleusercontent.com/p/AF1QipMERU...
# 4    https://lh5.googleusercontent.com/p/AF1QipOy4x...
# ..                                                 ...
# 295  https://lh5.googleusercontent.com/p/AF1QipNLMJ...
# 296  https://lh5.googleusercontent.com/p/AF1QipN7Vb...
# 297  https://lh5.googleusercontent.com/p/AF1QipNMIG...
# 298  https://lh5.googleusercontent.com/p/AF1QipMFbP...
# 299  https://lh5.googleusercontent.com/p/AF1QipNULN...
#
# [300 rows x 17 columns]

# %%
data.isna().sum()
# Out:
# Name               0
# Fulladdress        0
# Municipality       0
# Categories         0
# Time Zone          0
# Phones             0
# Claimed            0
# Review Count       0
# Average Rating     0
# Review URL         0
# Google Maps URL    0
# Latitude           0
# Longitude          0
# Website            0
# Domain             0
# Opening Hours      0
# Featured Image     0
# dtype: int64

# %% [markdown]
# #### Checking for Duplicated Data

# %%
duplicates = data.duplicated().sum()
print('The total of duplicated data is:', duplicates)
# Out:
# The total of duplicated data is: 40

# %%
duplicate_column = {}
for column in data.columns:
    duplicated_count = data[column].duplicated().sum()
    if duplicated_count > 0:
        duplicate_column[column] = duplicated_count

for column, count in duplicate_column.items():
    print(f"Column '{column} has {count} duplicated values")
# Out:
# Column 'Name has 48 duplicated values
# Column 'Fulladdress has 47 duplicated values
# Column 'Municipality has 159 duplicated values
# Column 'Categories has 284 duplicated values
# Column 'Time Zone has 299 duplicated values
# Column 'Phones has 104 duplicated values
# Column 'Claimed has 298 duplicated values
# Column 'Review Count has 187 duplicated values
# Column 'Average Rating has 286 duplicated values
# Column 'Review URL has 49 duplicated values
# Column 'Google Maps URL has 47 duplicated values
# Column 'Latitude has 47 duplicated values
# Column 'Longitude has 47 duplicated values
# Column 'Website has 229 duplicated values
# Column 'Domain has 258 duplicated values
# Column 'Opening Hours has 226 duplicated values
# Column 'Featured Image has 41 duplicated values

# %%
data = data.drop_duplicates(subset='Fulladdress')

# %%
duplicate_column = {}
for column in data.columns:
    duplicated_count = data[column].duplicated().sum()
    if duplicated_count >= 0:
        duplicate_column[column] = duplicated_count

for column, count in duplicate_column.items():
    print(f"Column '{column} has {count} duplicated values")
# Out:
# Column 'Name has 1 duplicated values
# Column 'Fulladdress has 0 duplicated values
# Column 'Municipality has 112 duplicated values
# Column 'Categories has 237 duplicated values
# Column 'Time Zone has 252 duplicated values
# Column 'Phones has 57 duplicated values
# Column 'Claimed has 251 duplicated values
# Column 'Review Count has 140 duplicated values
# Column 'Average Rating has 239 duplicated values
# Column 'Review URL has 2 duplicated values
# Column 'Google Maps URL has 0 duplicated values
# Column 'Latitude has 0 duplicated values
# Column 'Longitude has 0 duplicated values
# Column 'Website has 182 duplicated values
# Column 'Domain has 211 duplicated values
# Column 'Opening Hours has 179 duplicated values
# Column 'Featured Image has 1 duplicated values

# %% [markdown]
# data cleaned.
